# %%
from wordfreq import top_n_list
import nltk

# %%
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/tolek/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package wordnet to /Users/tolek/nltk_data...
# True

# %%
common = top_n_list('en', 1000)
tagged = nltk.pos_tag(common)

nouns = [word for word, tag in tagged if tag in ('NN', 'NNS')]

# %%
nouns
# Out:
# ['i',
#  'time',
#  'get',
#  'people',
#  "i'm",
#  'way',
#  'work',
#  'year',
#  'years',
#  'day',
#  'life',
#  'world',
#  "you're",
#  "that's",
#  'love',
#  'man',
#  'home',
#  'look',
#  'something',
#  'part',
#  'state',
#  'help',
#  'things',
#  'game',
#  'thing',
#  'give',
#  'house',
#  'place',
#  'school',
#  'mr',
#  'end',
#  'feel',
#  'team',
#  'family',
#  'money',
#  'someone',
#  'number',
#  'city',
#  'days',
#  'name',
#  'night',
#  'play',
#  'company',
#  "he's",
#  'thought',
#  'government',
#  'group',
#  'women',
#  'business',
#  'care',
#  'start',
#  'system',
#  'times',
#  'week',
#  'anything',
#  'case',
#  'nothing',
#  'person',
#  'today',
#  'everything',
#  'point',
#  "there's",
#  "doesn't",
#  'mean',
#  'music',
#  'power',
#  'states',
#  'water',
#  'head',
#  'men',
#  'job',
#  'line',
#  'order',
#  'party',
#  'run',
#  'service',
#  'country',
#  'season',
#  'children',
#  'everyone',
#  "they're",
#  'area',
#  'd',
# ...

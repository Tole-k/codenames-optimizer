# %%
from sentence_transformers import SentenceTransformer

# %%
sentences = ["Cow", "Farmer", "Engine"]

model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-mpnet-base-v2')
embeddings = model.encode(sentences)
print(embeddings)
# Out:
# Loading weights: 100%|██████████| 199/199 [00:00<00:00, 8509.02it/s]
# XLMRobertaModel LOAD REPORT from: sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [[-0.08403377  0.272138    0.00130403 ...  0.05554399  0.17309734
#   -0.12382604]
#  [-0.05404715  0.31908676 -0.00186766 ...  0.05917228  0.00463787
#   -0.03995919]
#  [-0.18835133  0.08847626 -0.01076754 ... -0.03099469 -0.12879525
#   -0.1155751 ]]
